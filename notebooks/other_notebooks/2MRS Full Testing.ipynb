# %%
import pandas as pd
from pandas import read_csv
import numpy as np
import os
from google.colab import drive
from astropy.io import ascii


drive.mount('/content/drive/')
os.chdir('/content/drive/My Drive/Physics Research/Fall 2024 Research')
# Out:
# Mounted at /content/drive/

# %%
from astropy.io import fits

# Open the FITS file
hdul = fits.open('2mrs_1175_done.fits')

# To view a summary of the file contents
hdul.info()
print('\n\n\n')

# If the data is in a table (usually in the second HDU)
data = hdul[1].data

# Print the column names
print(data.columns.names)

# To view the first few rows of the table
print(data[:5])

# Close the file
hdul.close()
# Out:
# Filename: 2mrs_1175_done.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    115   43533R x 29C   [16A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 4A, 5A, 2A, J, I, A, 19A, 28A]
#
#
#
#
# ['TMID', 'RA', 'DEC', 'GLON', 'GLAT', 'MKC', 'MHC', 'MJC', 'MKTC', 'MHTC', 'MJTC', 'EKC', 'EHC', 'EJC', 'EKTC', 'EHTC', 'EJTC', 'EBV', 'RISO', 'RTOT', 'BA', 'FLAGS', 'TYPE', 'TYPESRC', 'V', 'EV', 'VCAT', 'VSRC', 'CATID']
# [('00424433+4116074',  10.68471,  41.26875, 121.1743 , -21.57319, 0.797, 0.929, 1.552, 0.743, 0.881, 1.497, 0.016, 0.016, 0.015, 0.017, 0.017, 0.016, 0.683, 3.208, 3.491, 0.473, 'Z111', ' 3A2s', 'ZC', -300, 4, 'N', '1991RC3.9.C...0000d', 'MESSIER_031')
# ...

# %%
test_table = read_csv('mod_2mrs_1175_done.dat', delim_whitespace=True, header=None, on_bad_lines='skip')
print(test_table.head())
print(test_table.shape)
# Out:
# <ipython-input-7-90b46614f734>:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   test_table = read_csv('mod_2mrs_1175_done.dat', delim_whitespace=True, header=None, on_bad_lines='skip')
#                  0          1         2          3         4      5      6   \
# 0  00424433+4116074   10.68471  41.26875  121.17430 -21.57319  0.797  0.929
# 1  00473313-2517196   11.88806 -25.28880   97.36301 -87.96452  3.815  4.132
# 2  09553318+6903549  148.88826  69.06526  142.09190  40.90022  3.898  4.131
# 3  13252775-4301073  201.36565 -43.01871  309.51639  19.41761  3.948  4.244
# 4  13052727-4928044  196.36366 -49.46790  305.27151  13.34017  4.471  4.790
#
#       7      8      9   ...     19     20    21     22  23   24  25  26  \
# 0  1.552  0.743  0.881  ...  3.491  0.473  Z111   3A2s  ZC -300   4   N
# 1  4.858  3.765  4.077  ...  2.965  0.264  Z111   5X_s  ZC  243   2   N
# ...

# %%
table = read_csv('mod_with_headers_2mrs_1175_done.dat', delim_whitespace=True, on_bad_lines='skip')
print(table.head())
print(table.shape)
# Out:
# <ipython-input-8-4f865bf5e17a>:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   table = read_csv('mod_with_headers_2mrs_1175_done.dat', delim_whitespace=True, on_bad_lines='skip')
#                  ID      RAdeg    DECdeg          l         b    k_c    h_c  \
# 0  00424433+4116074   10.68471  41.26875  121.17430 -21.57319  0.797  0.929
# 1  00473313-2517196   11.88806 -25.28880   97.36301 -87.96452  3.815  4.132
# 2  09553318+6903549  148.88826  69.06526  142.09190  40.90022  3.898  4.131
# 3  13252775-4301073  201.36565 -43.01871  309.51639  19.41761  3.948  4.244
# 4  13052727-4928044  196.36366 -49.46790  305.27151  13.34017  4.471  4.790
#
#      j_c   k_tc   h_tc  ...  r_ext    b/a  flgs   type  ts    v  e_v  c  \
# 0  1.552  0.743  0.881  ...  3.491  0.473  Z111   3A2s  ZC -300    4  N
# 1  4.858  3.765  4.077  ...  2.965  0.264  Z111   5X_s  ZC  243    2  N
# ...

# %%
#To see potential inconsistencies with the table (have to use on_bad_lines parameter to avoid error)

with open('mod_with_headers_2mrs_1175_done.dat', 'r') as f:
    for i, line in enumerate(f):
        # Split the line by any whitespace
        fields = line.split()
        if len(fields) != 29:  # Assuming 29 fields are expected
            print(f"Line {i+1} has {len(fields)} fields: {line}")
# Out:
# Line 7046 has 30 fields: 13344722-4532508 203.69673 -45.54744 310.83176  16.65834 10.383 10.601 11.092  9.619  9.821 10.287 0.042 0.036 0.028 0.053 0.044 0.033 0.111 1.819 2.131 0.280 Z111  9B_s ZC    828   2 N 2004AJ....128...16K ESO_270-_G 017

# %% [markdown]
# One row had a data entry error where the underscore between G and 017 was instead a space (I checked other entries with the ESO prefix and they had a underscore between G and their specific trailing number). Updated the entry and not don't have to skip any lines (or in this case just one erroneous line).
#
# Note: Updated file replaced exisiting mod_with_headers file, so above code, when rerun, will not show the error with Line 7064.

# %%
table = read_csv('mod_with_headers_2mrs_1175_done.dat', delim_whitespace=True)
print(table.head())
print(table.shape)
# Out:
# <ipython-input-10-4f865bf5e17a>:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   table = read_csv('mod_with_headers_2mrs_1175_done.dat', delim_whitespace=True, on_bad_lines='skip')
#                  ID      RAdeg    DECdeg          l         b    k_c    h_c  \
# 0  00424433+4116074   10.68471  41.26875  121.17430 -21.57319  0.797  0.929
# 1  00473313-2517196   11.88806 -25.28880   97.36301 -87.96452  3.815  4.132
# 2  09553318+6903549  148.88826  69.06526  142.09190  40.90022  3.898  4.131
# 3  13252775-4301073  201.36565 -43.01871  309.51639  19.41761  3.948  4.244
# 4  13052727-4928044  196.36366 -49.46790  305.27151  13.34017  4.471  4.790
#
#      j_c   k_tc   h_tc  ...  r_ext    b/a  flgs   type  ts    v  e_v  c  \
# 0  1.552  0.743  0.881  ...  3.491  0.473  Z111   3A2s  ZC -300    4  N
# 1  4.858  3.765  4.077  ...  2.965  0.264  Z111   5X_s  ZC  243    2  N
# ...

# %%
#Create cleaned csv of the 2mrs_1175_done.dat file to be used elsewhere
table.to_csv('2mrs_1175_done_cleaned.csv', index = False)

# %%
#Read in the cleaned file to test it was created accurately
test_clean = read_csv('2mrs_1175_done_cleaned.csv')
print(test_clean.head())
print(test_clean.shape)
# Out:
#                  ID      RAdeg    DECdeg          l         b    k_c    h_c  \
# 0  00424433+4116074   10.68471  41.26875  121.17430 -21.57319  0.797  0.929
# 1  00473313-2517196   11.88806 -25.28880   97.36301 -87.96452  3.815  4.132
# 2  09553318+6903549  148.88826  69.06526  142.09190  40.90022  3.898  4.131
# 3  13252775-4301073  201.36565 -43.01871  309.51639  19.41761  3.948  4.244
# 4  13052727-4928044  196.36366 -49.46790  305.27151  13.34017  4.471  4.790
#
#      j_c   k_tc   h_tc  ...  r_ext    b/a  flgs   type  ts    v  e_v  c  \
# 0  1.552  0.743  0.881  ...  3.491  0.473  Z111   3A2s  ZC -300    4  N
# 1  4.858  3.765  4.077  ...  2.965  0.264  Z111   5X_s  ZC  243    2  N
# 2  4.784  3.803  4.043  ...  2.878  0.517  Z111   2A2s  ZC  -34    4  N
# 3  4.931  3.901  4.203  ...  2.613  0.957  Z111  -2__P  ZC  547    5  N
# 4  5.508  4.421  4.735  ...  2.772  0.308  Z111   6B_s  ZC  563    3  N
#
#                   vsrc       CAT_ID
# 0  1991RC3.9.C...0000d  MESSIER_031
# ...
